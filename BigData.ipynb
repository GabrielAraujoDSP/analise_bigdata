# %%
import pandas as pd

#cria um dataframe instanciando no objeto "df"
df = pd.read_csv("BaseDPEvolucaoMensalCisp (1).csv",sep = ";", encoding = "latin1")
df.head()
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3     6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4     7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
# 3           6  ...  NaN   NaN      26                      2
# 4           4  ...  NaN   NaN      10                      1
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# ...

# %%
#mostra a quantidade de linhas e colunas da tabela
df.shape
# Out:
# (37314, 65)

# %%
#mostra o nome das colunas
df.columns.tolist()

# %%
#mostra o tipo das colunas
df[['mes', 'ano', 'munic', 'regiao', 'furto_veiculos', 'recuperacao_veiculos']].dtypes
# Out:
# mes                     int64
# ano                     int64
# munic                     str
# regiao                    str
# furto_veiculos          int64
# recuperacao_veiculos    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37314 entries, 0 to 37313
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        37314 non-null  int64
#  1   mes                         37314 non-null  int64
#  2   ano                         37314 non-null  int64
#  3   mes_ano                     37314 non-null  str
#  4   aisp                        37314 non-null  int64
#  5   risp                        37314 non-null  int64
#  6   munic                       37314 non-null  str
#  7   mcirc                       37314 non-null  int64
#  8   regiao                      37314 non-null  str
#  9   hom_doloso                  37314 non-null  int64
#  10  lesao_corp_morte            37314 non-null  int64
#  11  latrocinio                  37314 non-null  int64
#  12  cvli                        37314 non-null  int64
# ...

# %%
#mostra as estatisticas das colunas (todas ou as que eu selecionar). Neste caso filtrei somente pela de furto e recuperação
df[['mes', 'ano', 'munic', 'regiao', 'furto_veiculos', 'recuperacao_veiculos']].describe().T
# Out:
#                         count         mean        std     min     25%     50%  \
# mes                   37314.0     6.482232   3.461767     1.0     3.0     6.0
# ano                   37314.0  2014.188723   6.625316  2003.0  2008.0  2014.0
# furto_veiculos        37314.0    11.005092  13.832270     0.0     1.0     6.0
# recuperacao_veiculos  37314.0    13.947044  24.547743     0.0     1.0     4.0
#
#                          75%     max
# mes                      9.0    12.0
# ano                   2020.0  2026.0
# furto_veiculos          16.0   173.0
# recuperacao_veiculos    16.0   359.0

# %%
#mostra as celulas com valor null ou soma todas
df[['mes', 'ano', 'munic', 'regiao', 'furto_veiculos', 'recuperacao_veiculos']].isnull().sum()
# Out:
# mes                     0
# ano                     0
# munic                   0
# regiao                  0
# furto_veiculos          0
# recuperacao_veiculos    0
# dtype: int64

# %%
#para usar uma coluna especifica, independentemente em qual função, usar dessa forma
df['']

# %%
#mostra a soma de todas as linhas das colunas que quiser
print(f"Número total de furto de veículos: {df['furto_veiculos'].sum()}")
print(f"Número total de recuperação de veículos: {df['recuperacao_veiculos'].sum()}")
# Out:
# Número total de furto de veículos: 410644
# Número total de recuperação de veículos: 520420

# %%
print(f'A média mensal de furtos de veículos no estado do RJ é: {df['furto_veiculos'].mean():.2f}')
print(f'A média mensal de recuperação de veículos no estado do RJ é: {df['recuperacao_veiculos'].mean():.2f}')
# Out:
# A média mensal de furtos de veículos no estado do RJ é: 11.01
# A média mensal de recuperação de veículos no estado do RJ é: 13.95

# %%
df['regiao'].value_counts()
# Out:
# regiao
# Interior                         18192
# Capital                          11197
# Baixada Fluminense                5155
# Grande NiterÃÂÃÂÃÂÃÂ³i     2610
# Grande Niterói                     160
# Name: count, dtype: int64
