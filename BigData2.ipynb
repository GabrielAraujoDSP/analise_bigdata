# %%
import pandas as pd

#cria um dataframe instanciando no objeto "df"
df = pd.read_csv("BaseDPEvolucaoMensalCisp (1).csv",sep = ";", encoding = "latin1")

# %%
#Padronizando os nomes da região Grande Niterói
df['regiao'] = df['regiao'].replace({
    'Grande NiterÃÂÃÂÃÂÃÂ³i': 'Grande Niterói',
})

# %%
#Criando variáveis para cada região de 2003 à 2026

#Criando uma variável com os dados somente da Capital
df_capital = df[(df['regiao'] == 'Capital') & (df['furto_veiculos'] >= 0)]
df_capital_tratada = df_capital[]
#df_capital = df[df['regiao'] == 'Capital']


#Criando uma variável com os dados somente da Baixada Fluminense
df_baixada_fluminense = df[df['regiao'] == 'Baixada Fluminense']

#Criando uma variável com os dados somente da Grande Niterói
df_grande_niteroi = df[df['regiao'] == 'Grande Niterói']

#Criando uma variável com os dados somente do Interior
df_interior = df[df['regiao'] == 'Interior']

# %%
df['regiao'].value_counts()

# %%
df_capital[['ano', 'regiao','furto_veiculos', 'recuperacao_veiculos',]]
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 37213    40    1  2026  2026m01     9     2  Rio de Janeiro  3304557  Capital
# 37214    41    1  2026  2026m01    18     2  Rio de Janeiro  3304557  Capital
# 37215    42    1  2026  2026m01    31     2  Rio de Janeiro  3304557  Capital
# 37216    43    1  2026  2026m01    27     2  Rio de Janeiro  3304557  Capital
# 37217    44    1  2026  2026m01     3     1  Rio de Janeiro  3304557  Capital
#
#        hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0               0  ...   NaN   NaN      21                      2
# 1               3  ...   NaN   NaN      15                      6
# 2               3  ...   NaN   NaN      47                      2
# 3               6  ...   NaN   NaN      26                      2
# 4               4  ...   NaN   NaN      10                      1
# ...           ...  ...   ...   ...     ...                    ...
# 37213           3  ...   3.0   2.0      38                      5
# 37214           2  ...   5.0   0.0      37                      3
# 37215           2  ...  15.0   6.0     113                      7
# 37216           0  ...   3.0   0.0     103                     11
# 37217           1  ...  12.0   0.0      32                      3
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 1                     0                1                          0
# 2                     1                0                          0
# 3                     1                0                          0
# 4                     3                0                          0
# ...                 ...              ...                        ...
# 37213                 1                0                          0
# 37214                 1                0                          0
# 37215                 0                0                          0
# 37216                 0                0                          0
# 37217                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 1                          0                   441     3
# 2                          0                   637     3
# 3                          0                   473     3
# 4                          0                   147     3
# ...                      ...                   ...   ...
# 37213                      0                   689     2
# 37214                      0                   858     2
# 37215                      0                  1444     2
# 37216                      0                   645     2
# 37217                      0                   853     2
#
# [11197 rows x 65 columns]
